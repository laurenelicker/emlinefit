# %%
import emlinefit
import importlib
importlib.reload(emlinefit)
import numpy as np

# %%
flux = np.genfromtxt("data/flux_sample.txt")
wavelength = np.genfromtxt("data/wavelength_sample.txt")
fit = emlinefit.emlinefit(wavelength, flux, 1625, 1630, fit_type='gaussian')
params = fit.return_result()
print(params)
fit.plot_fit()
# Out:
# {'amplitude': np.float64(4.59953435e-15), 'mean': np.float64(1627.5), 'stddev': np.float64(2.5), 'covariance': array([[1.30433243e-31, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])}
