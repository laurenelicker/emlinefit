# %%
import emlinefit
import importlib
importlib.reload(emlinefit)
import numpy as np

# %%
flux = np.genfromtxt("data/flux_sample.txt")
wavelength = np.genfromtxt("data/wavelength_sample.txt")
fit = emlinefit.emlinefit(wavelength, flux, 1600, 1700)
params = fit.return_result()
print(params)
fit.plot_fit()
# Out:
# (np.float64(4.59953435e-15), np.float64(1650.0), np.float64(50.0), array([[1.44268759e-32, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]))
